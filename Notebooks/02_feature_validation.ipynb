# %%
import torch
from models.train_model import Trainer

data_csv = "../data/trials.csv"
trainer = Trainer(data_csv, model_path="../models/checkpoint.pt", device="cuda" if torch.cuda.is_available() else "cpu")

# Train the model for 5 epochs as a demo
trainer.train(epochs=5, batch_size=16, lr=1e-3, val_split=0.2)
